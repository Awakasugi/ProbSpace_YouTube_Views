# %%
import numpy as np
import pandas as pd
import pandas_profiling
import seaborn

# %%
train = pd.read_csv('train_data.csv')
test = pd.read_csv('test_data.csv')

# %%
train.tail(10)
# Out:
#           id     video_id                                              title  \
# 19710  19711  oCdEHl3XAXg                 カズが行く！隙間男の撮影現場レポートStalking Vampire
# 19711  19712  FAGNpyBdOmA                        Green-Tea Harvester  乗用茶摘採機
# 19712  19713  azwbRAe87Co  Trick Shot Battle | Brodie Smith vs. Avery Jen...
# 19713  19714  RzFFaLB6fHw                   映画『プロメア』第二弾PV 制作：TRIGGER（5月全国公開）
# 19714  19715  3bjF4O0qTmQ     serendipity - the power of the secret surf hut
# 19715  19716  _TUaovTvjpY  博多名物！塩もつ鍋♪  Salt Based Motsu Nabe♪ (Hakata Spe...
# 19716  19717  h_w58wfeyYk             「千利休」 踊る授業シリーズ 【踊ってみたんすけれども】 エグスプロージョン
# 19717  19718  CfsyUyi_FJM                   Sleeping Beauty Official Trailer
# 19718  19719  qcGrgLUpVr8                  【アニマート動物病院】病院猫スケさんのボールキャッチ！！PART2
# 19719  19720  DHf_Ihnxa3I                  【ニンテンドースイッチ】引きこもり2人が仲良く(？）スニッパーズ！
#
#                     publishedAt                 channelId  \
# 19710  2013-03-10T08:24:11.000Z  UCVPz_nauEJpqPxxvYiOpCHQ
# ...

# %%
test.profile_report()
# Out:
# ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-08617373940c> in <module>
# ----> 1 test.profile_report()
#
# /usr/local/var/pyenv/versions/miniconda3-4.3.27/lib/python3.6/site-packages/pandas_profiling/controller/pandas_decorator.py in profile_report(df, **kwargs)
#      15         A ProfileReport of the DataFrame.
#      16     """
# ---> 17     p = ProfileReport(df, **kwargs)
#      18     return p
#      19
#
# /usr/local/var/pyenv/versions/miniconda3-4.3.27/lib/python3.6/site-packages/pandas_profiling/__init__.py in __init__(self, df, minimal, config_file, **kwargs)
#      61
#      62         # Get dataset statistics
# ---> 63         description_set = describe_df(df)
#      64
#      65         # Build report structure
#
# /usr/local/var/pyenv/versions/miniconda3-4.3.27/lib/python3.6/site-packages/pandas_profiling/model/describe.py in describe(df)
# ...

# %%
def show_data()

# %%
def main():
    read_csv()

# %%
main()
